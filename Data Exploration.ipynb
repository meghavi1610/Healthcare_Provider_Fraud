# %%
import pandas as pd

# %%
train=pd.read_csv("Train-1542865627584.csv")
train_b=pd.read_csv("Train_Beneficiarydata-1542865627584.csv")
train_ip=pd.read_csv("Train_Inpatientdata-1542865627584.csv")
train_op=pd.read_csv("Train_Outpatientdata-1542865627584.csv")

# %%
train.columns
# Out:
# Index(['Provider', 'PotentialFraud'], dtype='object')

# %% [markdown]
# *Beneficiary Table*
#
# This data contains beneficiary KYC details like health conditions,regioregion they belong to etc.

# %%
train_b.columns
# Out:
# Index(['BeneID', 'DOB', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt'],
#       dtype='object')

# %%
train_b.head(5)
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       2                     2                          2
# 2                       2                     2                          1
# 3                       2                     1                          1
# 4                       2                     1                          2
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         2                                2
# 2                         2                                2
# 3                         1                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   2                         0                      0
# 2                   2                         0                      0
# 3                   2                         0                      0
# 4                   2                         0                      0
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                        60                     70
# 1                        30                     50
# 2                        90                     40
# 3                      1810                    760
# 4                      1790                   1200
#
# [5 rows x 25 columns]

# %% [markdown]
# *Inpatient Data*
#
# This data provides insights about the claims filed for those patients who are admitted in the hospitals. It also provides additional details like their admission and discharge dates and admited diagnosis code.

# %%
train_ip.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
train_ip.head(5)
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# 2      PHY324689  2009-09-17  ...                NaN                 NaN
# 3      PHY349768  2009-02-14  ...              25062               40390
# 4            NaN  2009-08-13  ...               5119               29620
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0               5849                 NaN                NaN
# 1                NaN                 NaN             7092.0
# 2                NaN                 NaN                NaN
# 3               4019                 NaN              331.0
# 4              20300                 NaN             3893.0
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# *Outpatient Data*
#
# This data provides details about the claims filed for those patients who visit hospitals and not admitted in it.

# %%
train_op.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode'],
#       dtype='object')

# %%
train_op.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# 2            NaN               2723  ...                NaN
# 3            NaN              71988  ...                NaN
# 4            NaN              82382  ...                NaN
#
#   ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#   ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   DeductibleAmtPaid  ClmAdmitDiagnosisCode
# 0                 0                  56409
# 1                 0                  79380
# 2                 0                    NaN
# 3                 0                    NaN
# 4                 0                  71947
#
# [5 rows x 27 columns]

# %%
train_df = pd.concat([train_ip, train_op], ignore_index=True)

# %%
train_df.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  558211 non-null  object
#  1   ClaimID                 558211 non-null  object
#  2   ClaimStartDt            558211 non-null  object
#  3   ClaimEndDt              558211 non-null  object
#  4   Provider                558211 non-null  object
#  5   InscClaimAmtReimbursed  558211 non-null  int64
#  6   AttendingPhysician      556703 non-null  object
#  7   OperatingPhysician      114447 non-null  object
#  8   OtherPhysician          199736 non-null  object
#  9   AdmissionDt             40474 non-null   object
#  10  ClmAdmitDiagnosisCode   145899 non-null  object
#  11  DeductibleAmtPaid       557312 non-null  float64
#  12  DischargeDt             40474 non-null   object
#  13  DiagnosisGroupCode      40474 non-null   object
#  14  ClmDiagnosisCode_1      547758 non-null  object
#  15  ClmDiagnosisCode_2      362605 non-null  object
#  16  ClmDiagnosisCode_3      243055 non-null  object
#  17  ClmDiagnosisCode_4      164536 non-null  object
#  18  ClmDiagnosisCode_5      111924 non-null  object
#  19  ClmDiagnosisCode_6      84392 non-null   object
#  20  ClmDiagnosisCode_7      66177 non-null   object
#  21  ClmDiagnosisCode_8      53444 non-null   object
#  22  ClmDiagnosisCode_9      41815 non-null   object
#  23  ClmDiagnosisCode_10     5010 non-null    object
#  24  ClmProcedureCode_1      23310 non-null   float64
#  25  ClmProcedureCode_2      5490 non-null    float64
#  26  ClmProcedureCode_3      969 non-null     float64
#  27  ClmProcedureCode_4      118 non-null     float64
#  28  ClmProcedureCode_5      9 non-null       float64
#  29  ClmProcedureCode_6      0 non-null       float64
# dtypes: float64(7), int64(1), object(22)
# memory usage: 127.8+ MB

# %%
import networkx as nx

source = 'Provider'
target = 'AttendingPhysician'

G = nx.from_pandas_edgelist(train_df, source=source, target = target)

# %%
# Remove rows with NaN values in specified columns
train_df.dropna(subset=['Provider', 'OperatingPhysician', 'AttendingPhysician'], inplace=True)

# %%
train_df.shape
# Out:
# (114433, 32)

# %%
len(train_df['BeneID'].unique())
# Out:
# 71030

# %%
len(train_df['OperatingPhysician'].unique())
# Out:
# 35313

# %%
len(train_df['AttendingPhysician'].unique())
# Out:
# 36461

# %%
df=[]

# %%
df=train_df

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create a list to store tuples
tuples_list = []

# Iterate over each row in the DataFrame and create tuples
for index, row in df.iterrows():
    provider = row['Provider']
    operating_physician = row['OperatingPhysician']
    attending_physician = row['AttendingPhysician']
    tuples_list.append((provider, operating_physician, attending_physician))


# Create a new graph
G = nx.Graph()

# Add nodes for each component and specify subsets
for data in tuples_list:
    G.add_nodes_from(data, subset=data[0])  # Assuming the provider is the subset

# Add edges between components
for data in tuples_list:
    G.add_edges_from([(data[0], data[1]), (data[0], data[2])])

# Create a figure and axes
plt.figure(figsize=(12, 8))

# Compute the layout
pos_layout = nx.multipartite_layout(G, subset_key="subset")

# Draw the graph with adjusted parameters
nx.draw_networkx(G, pos_layout, with_labels=True, node_size=300, node_color='skyblue', font_size=12, font_weight='bold')

# Add title
plt.title('Tripartite Graph')

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Function to compute BiRank scores for a bipartite graph
def birank_scores(graph):
    # Initialize BiRank scores dictionary
    birank = {}
    
    # Initialize scores for providers and physicians
    provider_scores = nx.pagerank(graph, max_iter=500)
    physician_scores = nx.pagerank(graph, max_iter=500)
    
    # Update BiRank scores dictionary
    birank['providers'] = provider_scores
    birank['physicians'] = physician_scores
    
    return birank

# Create two bipartite graphs: provider - operating physician and provider - attending physician
provider_op_physician_graph = nx.Graph()
provider_attending_physician_graph = nx.Graph()

# Add nodes for providers and physicians
providers = set()
operating_physicians = set()
attending_physicians = set()

for provider, operating_physician, attending_physician in tuples_list:
    providers.add(provider)
    operating_physicians.add(operating_physician)
    attending_physicians.add(attending_physician)

provider_op_physician_graph.add_nodes_from(providers, bipartite=0)
provider_op_physician_graph.add_nodes_from(operating_physicians, bipartite=1)

provider_attending_physician_graph.add_nodes_from(providers, bipartite=0)
provider_attending_physician_graph.add_nodes_from(attending_physicians, bipartite=1)

# Add edges between providers and physicians
for provider, operating_physician, attending_physician in tuples_list:
    provider_op_physician_graph.add_edge(provider, operating_physician)
    provider_attending_physician_graph.add_edge(provider, attending_physician)

# %%
import pandas as pd

# Assuming you have a DataFrame named df that contains the initial table

# Compute BiRank scores for provider - operating physician graph
birank_op = birank_scores(provider_op_physician_graph)

# Compute BiRank scores for provider - attending physician graph
birank_att = birank_scores(provider_attending_physician_graph)

# Add BiRank scores to the DataFrame
df['BiRank_Providers_OP'] = df['Provider'].map(birank_op['providers'])
df['BiRank_Providers_Att'] = df['Provider'].map(birank_att['providers'])

df
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# 5        BENE11017   CLM70950   2009-10-06  2009-10-12  PRV54986
# 6        BENE11018   CLM32075   2009-01-02  2009-01-07  PRV54090
# ...            ...        ...          ...         ...       ...
# 558198  BENE159198  CLM111191   2008-12-23  2009-01-12  PRV53676
# 558199  BENE159198  CLM172248   2009-02-02  2009-02-02  PRV53676
# 558201  BENE159198  CLM255268   2009-03-19  2009-03-19  PRV53672
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 1                         5000          PHY318495          PHY318495
# 3                         5000          PHY369659          PHY392961
# 4                        10000          PHY379376          PHY398258
# 5                         8000          PHY402711          PHY402711
# 6                         8000          PHY412314          PHY347494
# ...                        ...                ...                ...
# 558198                      60          PHY361063          PHY361063
# 558199                     400          PHY361063          PHY361063
# 558201                      70          PHY317739          PHY317739
# 558206                     800          PHY364188          PHY364188
# 558207                     400          PHY423019          PHY332284
#
#        OtherPhysician AdmissionDt  ... ClmDiagnosisCode_9  \
# 1                 NaN  2009-08-31  ...                NaN
# 3           PHY349768  2009-02-14  ...               4019
# 4                 NaN  2009-08-13  ...              20300
# 5           PHY402711  2009-10-06  ...              25002
# 6                 NaN  2009-01-02  ...              56210
# ...               ...         ...  ...                ...
# 558198            NaN         NaN  ...                NaN
# 558199            NaN         NaN  ...                NaN
# 558201      PHY423886         NaN  ...                NaN
# 558206      PHY385752         NaN  ...                NaN
# 558207            NaN         NaN  ...                NaN
#
#         ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 1                       NaN             7092.0                NaN
# 3                       NaN              331.0                NaN
# 4                       NaN             3893.0                NaN
# 5                       NaN              863.0                NaN
# 6                       NaN             4576.0                NaN
# ...                     ...                ...                ...
# 558198                  NaN                NaN                NaN
# 558199                  NaN                NaN                NaN
# 558201                  NaN                NaN                NaN
# 558206                  NaN                NaN                NaN
# 558207                  NaN                NaN                NaN
#
#        ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 1                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
# 5                     NaN                NaN                NaN
# 6                     NaN                NaN                NaN
# ...                   ...                ...                ...
# 558198                NaN                NaN                NaN
# 558199                NaN                NaN                NaN
# 558201                NaN                NaN                NaN
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
#
#        ClmProcedureCode_6 BiRank_Providers_OP BiRank_Providers_Att
# 1                     NaN            0.000493             0.000542
# 3                     NaN            0.000088             0.000085
# 4                     NaN            0.000083             0.000081
# 5                     NaN            0.000599             0.000594
# 6                     NaN            0.000160             0.000180
# ...                   ...                 ...                  ...
# 558198                NaN            0.000025             0.000024
# 558199                NaN            0.000025             0.000024
# 558201                NaN            0.000119             0.000115
# 558206                NaN            0.000083             0.000081
# 558207                NaN            0.000095             0.000093
#
# [114433 rows x 32 columns]

# %%
# Save DataFrame to CSV file
df.to_csv('data.csv', index=False)

# %%
pip install python-louvain
# Out:
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#      -------------------- ----------------- 112.6/204.6 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 204.6/204.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx in c:\users\megha\anaconda3\lib\site-packages (from python-louvain) (2.8.4)
# Requirement already satisfied: numpy in c:\users\megha\anaconda3\lib\site-packages (from python-louvain) (1.23.5)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9403 sha256=c62f3cc277f8bb90b861f408b1791071143140b5dade05c1043a34a5f386adea
#   Stored in directory: c:\users\megha\appdata\local\pip\cache\wheels\4d\7c\b6\79b198e4ec43f915fbdf967953d48b89a18893b12aa9df0ae2
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for bitarray: [Errno 2] No such file or directory: 'c:\\users\\megha\\anaconda3\\lib\\site-packages\\bitarray-2.4.1.dist-info\\METADATA'
# WARNING: Error parsing requirements for menuinst: [Errno 2] No such file or directory: 'c:\\users\\megha\\anaconda3\\lib\\site-packages\\menuinst-1.4.18.dist-info\\METADATA'
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from community import community_louvain  # Import the community_louvain function for Louvain algorithm

# Compute the partition using the Louvain algorithm
partition = community_louvain.best_partition(G)

# Draw the graph with community coloring
plt.figure(figsize=(12, 8))

# Draw nodes with community colors
nx.draw_networkx_nodes(G, pos_layout, node_size=300, node_color=list(partition.values()), cmap=plt.cm.tab10)

# Draw edges
nx.draw_networkx_edges(G, pos_layout, alpha=0.5)

# Draw labels
nx.draw_networkx_labels(G, pos_layout, font_size=12, font_weight='bold')

# Add title
plt.title('Tripartite Graph with Community Detection (Louvain)')

# Show the plot
plt.show()

# %%
import plotly.graph_objs as go

# %%
# Compute the layout
pos_layout = nx.multipartite_layout(G, subset_key="subset")

# Create edges
edge_trace = go.Scatter(x=[], y=[], line=dict(width=0.5, color='#888'), hoverinfo='none', mode='lines')

for edge in G.edges():
    x0, y0 = pos_layout[edge[0]]
    x1, y1 = pos_layout[edge[1]]
    edge_trace['x'] += (x0, x1, None)
    edge_trace['y'] += (y0, y1, None)

# %%
# Create nodes
node_trace = go.Scatter(x=[], y=[], text=[], mode='markers', hoverinfo='text', marker=dict(color=[], size=10, line=dict(width=2)))

for node in G.nodes():
    x, y = pos_layout[node]
    node_trace['x'] += (x,)  # Append x coordinate as a single-element tuple
    node_trace['y'] += (y,)  # Append y coordinate as a single-element tuple
    node_trace['text'] += (node,)  # Append node label as a single-element tuple
    node_trace['marker']['color'] += ('skyblue',)  # Append color as a single-element tuple

# Create figure
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='<br>Tripartite Graph',
                    titlefont=dict(size=16),
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    annotations=[dict(
                        text="",
                        showarrow=False,
                        xref="paper", yref="paper",
                        x=0.005, y=-0.002)],
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

# Update node_trace with labels
node_trace.update(textposition='top center', textfont=dict(color='black', size=10))

# Show plot
fig.show()
